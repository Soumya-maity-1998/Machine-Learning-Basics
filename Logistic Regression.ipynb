# %% [markdown]
# ## Logistic Regression with Scikit Learn - Machine Learning with Python

# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt

# %%
raw_df = pd.read_csv('Datasets/weatherAUS.csv')

# %%
raw_df
# Out:
#               Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  \
# 0       2008-12-01   Albury     13.4     22.9       0.6          NaN
# 1       2008-12-02   Albury      7.4     25.1       0.0          NaN
# 2       2008-12-03   Albury     12.9     25.7       0.0          NaN
# 3       2008-12-04   Albury      9.2     28.0       0.0          NaN
# 4       2008-12-05   Albury     17.5     32.3       1.0          NaN
# ...            ...      ...      ...      ...       ...          ...
# 145455  2017-06-21    Uluru      2.8     23.4       0.0          NaN
# 145456  2017-06-22    Uluru      3.6     25.3       0.0          NaN
# 145457  2017-06-23    Uluru      5.4     26.9       0.0          NaN
# 145458  2017-06-24    Uluru      7.8     27.0       0.0          NaN
# 145459  2017-06-25    Uluru     14.9      NaN       0.0          NaN
#
#         Sunshine WindGustDir  WindGustSpeed WindDir9am  ... Humidity9am  \
# ...

# %%
raw_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 145460 entries, 0 to 145459
# Data columns (total 23 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   Date           145460 non-null  object
#  1   Location       145460 non-null  object
#  2   MinTemp        143975 non-null  float64
#  3   MaxTemp        144199 non-null  float64
#  4   Rainfall       142199 non-null  float64
#  5   Evaporation    82670 non-null   float64
#  6   Sunshine       75625 non-null   float64
#  7   WindGustDir    135134 non-null  object
#  8   WindGustSpeed  135197 non-null  float64
#  9   WindDir9am     134894 non-null  object
#  10  WindDir3pm     141232 non-null  object
#  11  WindSpeed9am   143693 non-null  float64
#  12  WindSpeed3pm   142398 non-null  float64
#  13  Humidity9am    142806 non-null  float64
#  14  Humidity3pm    140953 non-null  float64
#  15  Pressure9am    130395 non-null  float64
# ...

# %%
# dropping non-null values from RainToday and RainTomorrow
raw_df.dropna(subset = ['RainToday', 'RainTomorrow'], inplace = True)

# %%
raw_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 140787 entries, 0 to 145458
# Data columns (total 23 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   Date           140787 non-null  object
#  1   Location       140787 non-null  object
#  2   MinTemp        140319 non-null  float64
#  3   MaxTemp        140480 non-null  float64
#  4   Rainfall       140787 non-null  float64
#  5   Evaporation    81093 non-null   float64
#  6   Sunshine       73982 non-null   float64
#  7   WindGustDir    131624 non-null  object
#  8   WindGustSpeed  131682 non-null  float64
#  9   WindDir9am     131127 non-null  object
#  10  WindDir3pm     137117 non-null  object
#  11  WindSpeed9am   139732 non-null  float64
#  12  WindSpeed3pm   138256 non-null  float64
#  13  Humidity9am    139270 non-null  float64
#  14  Humidity3pm    137286 non-null  float64
#  15  Pressure9am    127044 non-null  float64
#  16  Pressure3pm    127018 non-null  float64
# ...

# %%
import plotly.express as px 
import matplotlib 
import seaborn as sns 
# %matplotlib inline

sns.set_style('darkgrid')
matplotlib.rcParams['font.size'] = 14
matplotlib.rcParams['figure.figsize'] = (8, 6)
matplotlib.rcParams['figure.facecolor'] = '#000000'

# %%
px.histogram(raw_df, 
             x = 'Temp3pm', 
             title = 'Temperature vs Rainy days', color = 'RainToday')

# %%
px.histogram(raw_df, 
             x = 'Location', 
             title = 'Location vs Rainy days', color = 'RainToday')

# %%
px.histogram(raw_df, 
             x = 'Temp3pm', 
             title = 'Location vs Rainy days', color = 'RainTomorrow')

# %%
px.histogram(raw_df, 
             x = 'RainToday', 
             title = 'Location vs Rainy days', color = 'RainTomorrow')

# %%
matplotlib.rcParams['figure.figsize'] = (10,8)
#plt.Figure(figsize=(5,5))
px.scatter(raw_df.sample(2000), 
           title = 'Min Temp vs Max Temp', 
           x = 'MinTemp', y = 'MaxTemp', color = 'RainToday')

# %%
px.strip(raw_df.sample(2000),
         title = 'Temp(3pm) vs Humidity(3pm)', 
         x = 'Temp3pm', 
         y = 'Humidity3pm', 
         color = 'RainTomorrow')

# %%
from sklearn.model_selection import train_test_split as tts

# %%
train_val_df, test_df = tts(raw_df, test_size = 0.2, random_state = 42)
train_df, val_df = tts(train_val_df, test_size = 0.25, random_state = 42)

# %%
print(train_df.shape, val_df.shape, test_df.shape)
# Out:
# (84471, 23) (28158, 23) (28158, 23)

# %%
plt.title('No. of Rows per Year', color = 'red')
plt.xlabel('Date', color = 'white')
plt.ylabel('Counts', color = 'white')
plt.tick_params(colors = 'white')

sns.countplot(x = pd.to_datetime(raw_df.Date).dt.year, 
              palette = 'Set1')
# Out:
# C:\Users\SOUMYADIP\AppData\Local\Temp\ipykernel_18424\1892183471.py:6: FutureWarning:
#
#
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
# <Axes: title={'center': 'No. of Rows per Year'}, xlabel='Date', ylabel='Counts'>

# %%
year = pd.to_datetime(raw_df.Date).dt.year

train_df = raw_df[year < 2015]
val_df = raw_df[year == 2015]
test_df = raw_df[year > 2015]

# %%
input_cols = list(train_df.columns)[1:-1] # starting from location column to the column before target 
target_col = 'RainTomorrow'

# %%
print(input_cols)
# Out:
# ['Location', 'MinTemp', 'MaxTemp', 'Rainfall', 'Evaporation', 'Sunshine', 'WindGustDir', 'WindGustSpeed', 'WindDir9am', 'WindDir3pm', 'WindSpeed9am', 'WindSpeed3pm', 'Humidity9am', 'Humidity3pm', 'Pressure9am', 'Pressure3pm', 'Cloud9am', 'Cloud3pm', 'Temp9am', 'Temp3pm', 'RainToday']

# %% [markdown]
# ### We can now create inputs and targets for the training, validation and test for further processing and model training

# %%
train_inputs = train_df[input_cols].copy()      # copy is for not disturbing the original data
train_targets = train_df[target_col].copy()

val_inputs = val_df[input_cols].copy()
val_targets = val_df[target_col].copy()

test_inputs = test_df[input_cols].copy()
test_targets = test_df[target_col].copy()

# %%
# seeing which columns are numerical and which are categorical

numeric_cols = train_inputs.select_dtypes(include = np.number).columns.tolist() # tells which are numeric columns 
categorical_cols = train_inputs.select_dtypes('object').columns.tolist()

# %%
numeric_cols
# Out:
# ['MinTemp',
#  'MaxTemp',
#  'Rainfall',
#  'Evaporation',
#  'Sunshine',
#  'WindGustSpeed',
#  'WindSpeed9am',
#  'WindSpeed3pm',
#  'Humidity9am',
#  'Humidity3pm',
#  'Pressure9am',
#  'Pressure3pm',
#  'Cloud9am',
#  'Cloud3pm',
#  'Temp9am',
#  'Temp3pm']

# %%
categorical_cols
# Out:
# ['Location', 'WindGustDir', 'WindDir9am', 'WindDir3pm', 'RainToday']

# %%
train_df[numeric_cols].describe()
# Out:
#             MinTemp       MaxTemp      Rainfall   Evaporation      Sunshine  \
# count  97674.000000  97801.000000  97988.000000  61657.000000  57942.000000
# mean      12.007831     23.022202      2.372935      5.289991      7.609004
# std        6.347175      6.984397      8.518819      3.952010      3.788813
# min       -8.500000     -4.100000      0.000000      0.000000      0.000000
# 25%        7.500000     17.900000      0.000000      2.600000      4.800000
# 50%       11.800000     22.400000      0.000000      4.600000      8.500000
# 75%       16.600000     27.900000      0.800000      7.200000     10.600000
# max       33.900000     48.100000    371.000000     82.400000     14.300000
#
#        WindGustSpeed  WindSpeed9am  WindSpeed3pm   Humidity9am   Humidity3pm  \
# count   91160.000000  97114.000000  96919.000000  96936.000000  96872.000000
# mean       40.215873     14.092263     18.764608     68.628745     51.469547
# ...

# %%
train_inputs[categorical_cols].nunique() # Tells how many unique categories are there.
# Out:
# Location       49
# WindGustDir    16
# WindDir9am     16
# WindDir3pm     16
# RainToday       2
# dtype: int64

# %% [markdown]
# #### Imputing Missing Numeric Data

# %%
from sklearn.impute import SimpleImputer

# %%
imputer = SimpleImputer(strategy = 'mean')

# %%
# No. of missing values in each column 
raw_df[numeric_cols].isna().sum()
# Out:
# MinTemp            468
# MaxTemp            307
# Rainfall             0
# Evaporation      59694
# Sunshine         66805
# WindGustSpeed     9105
# WindSpeed9am      1055
# WindSpeed3pm      2531
# Humidity9am       1517
# Humidity3pm       3501
# Pressure9am      13743
# Pressure3pm      13769
# Cloud9am         52625
# Cloud3pm         56094
# Temp9am            656
# Temp3pm           2624
# dtype: int64

# %%
train_inputs[numeric_cols].isna().sum()
# Out:
# MinTemp            314
# MaxTemp            187
# Rainfall             0
# Evaporation      36331
# Sunshine         40046
# WindGustSpeed     6828
# WindSpeed9am       874
# WindSpeed3pm      1069
# Humidity9am       1052
# Humidity3pm       1116
# Pressure9am       9112
# Pressure3pm       9131
# Cloud9am         34988
# Cloud3pm         36022
# Temp9am            574
# Temp3pm            596
# dtype: int64

# %%
imputer.fit(raw_df[numeric_cols])
# Out:
# SimpleImputer()

# %%
list(imputer.statistics_)
# Out:
# [np.float64(12.184823865620478),
#  np.float64(23.235120301822324),
#  np.float64(2.349974074310839),
#  np.float64(5.472515506887154),
#  np.float64(7.630539861047283),
#  np.float64(39.97051988882308),
#  np.float64(13.990496092519967),
#  np.float64(18.631140782316862),
#  np.float64(68.82683277087672),
#  np.float64(51.44928834695453),
#  np.float64(1017.6545771543716),
#  np.float64(1015.2579625879797),
#  np.float64(4.431160817585808),
#  np.float64(4.499250233195188),
#  np.float64(16.987066387879914),
#  np.float64(21.693182690011074)]

# %%
train_inputs
# Out:
#        Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0        Albury     13.4     22.9       0.6          NaN       NaN
# 1        Albury      7.4     25.1       0.0          NaN       NaN
# 2        Albury     12.9     25.7       0.0          NaN       NaN
# 3        Albury      9.2     28.0       0.0          NaN       NaN
# 4        Albury     17.5     32.3       1.0          NaN       NaN
# ...         ...      ...      ...       ...          ...       ...
# 144548    Uluru     16.9     33.2       0.0          NaN       NaN
# 144549    Uluru     15.1     36.8       0.0          NaN       NaN
# 144550    Uluru     17.3     37.8       0.0          NaN       NaN
# 144551    Uluru     20.1     38.5       0.0          NaN       NaN
# 144552    Uluru     22.5     39.6       0.0          NaN       NaN
#
#        WindGustDir  WindGustSpeed WindDir9am WindDir3pm  ...  WindSpeed3pm  \
# 0                W           44.0          W        WNW  ...          24.0
# ...

# %%
imputer.transform(train_inputs[numeric_cols])   # Creates a numpy array
# Out:
# array([[13.4       , 22.9       ,  0.6       , ...,  4.49925023,
#         16.9       , 21.8       ],
#        [ 7.4       , 25.1       ,  0.        , ...,  4.49925023,
#         17.2       , 24.3       ],
#        [12.9       , 25.7       ,  0.        , ...,  2.        ,
#         21.        , 23.2       ],
#        ...,
#        [17.3       , 37.8       ,  0.        , ...,  4.49925023,
#         29.7       , 35.7       ],
#        [20.1       , 38.5       ,  0.        , ...,  4.49925023,
#         29.8       , 37.2       ],
#        [22.5       , 39.6       ,  0.        , ...,  4.49925023,
#         30.1       , 37.4       ]], shape=(97988, 16))

# %%
train_inputs[numeric_cols] = imputer.transform(train_inputs[numeric_cols])  # overwriting and imputing. This creates a data frame 
val_inputs[numeric_cols] = imputer.transform(val_inputs[numeric_cols])
test_inputs[numeric_cols] = imputer.transform(test_inputs[numeric_cols])

# %%
train_inputs[numeric_cols]
# Out:
#         MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  WindGustSpeed  \
# 0          13.4     22.9       0.6     5.472516   7.63054           44.0
# 1           7.4     25.1       0.0     5.472516   7.63054           44.0
# 2          12.9     25.7       0.0     5.472516   7.63054           46.0
# 3           9.2     28.0       0.0     5.472516   7.63054           24.0
# 4          17.5     32.3       1.0     5.472516   7.63054           41.0
# ...         ...      ...       ...          ...       ...            ...
# 144548     16.9     33.2       0.0     5.472516   7.63054           43.0
# 144549     15.1     36.8       0.0     5.472516   7.63054           31.0
# 144550     17.3     37.8       0.0     5.472516   7.63054           39.0
# 144551     20.1     38.5       0.0     5.472516   7.63054           43.0
# 144552     22.5     39.6       0.0     5.472516   7.63054           76.0
#
#         WindSpeed9am  WindSpeed3pm  Humidity9am  Humidity3pm  Pressure9am  \
# ...

# %%
train_inputs[numeric_cols].isna().sum()
# Out:
# MinTemp          0
# MaxTemp          0
# Rainfall         0
# Evaporation      0
# Sunshine         0
# WindGustSpeed    0
# WindSpeed9am     0
# WindSpeed3pm     0
# Humidity9am      0
# Humidity3pm      0
# Pressure9am      0
# Pressure3pm      0
# Cloud9am         0
# Cloud3pm         0
# Temp9am          0
# Temp3pm          0
# dtype: int64

# %% [markdown]
# #### Scaling Numeric Features

# %%
raw_df[numeric_cols].describe()
# Out:
#              MinTemp       MaxTemp       Rainfall   Evaporation      Sunshine  \
# count  140319.000000  140480.00000  140787.000000  81093.000000  73982.000000
# mean       12.184824      23.23512       2.349974      5.472516      7.630540
# std         6.403879       7.11450       8.465173      4.189132      3.781729
# min        -8.500000      -4.80000       0.000000      0.000000      0.000000
# 25%         7.600000      17.90000       0.000000      2.600000      4.900000
# 50%        12.000000      22.60000       0.000000      4.800000      8.500000
# 75%        16.800000      28.30000       0.800000      7.400000     10.700000
# max        33.900000      48.10000     371.000000    145.000000     14.500000
#
#        WindGustSpeed   WindSpeed9am   WindSpeed3pm    Humidity9am  \
# count  131682.000000  139732.000000  138256.000000  139270.000000
# mean       39.970520      13.990496      18.631141      68.826833
# std        13.578201       8.886210       8.798096      19.063650
# ...

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler = MinMaxScaler()
